# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import Series, DataFrame

# %%
data = pd.read_csv('compTimes.log')
dataClean = data.dropna()
data.head()
# Out:
#                     file  optLevel  foundSolution  solutionLength  compTime
# 0  ./Bombastic5_10.param         0           True              10     5.639
# 1  ./Bombastic5_10.param         1           True              10     6.123
# 2  ./Bombastic5_10.param         2           True              10     7.316
# 3  ./Bombastic5_10.param         3           True              10     8.477
# 4  ./Bombastic8_15.param         0          False              15   234.150

# %%
data.dropna().groupby('optLevel').agg({'compTime':['mean','std'],'solutionLength':['mean']})
#data.dropna().groupby('optLevel').agg({'compTime':['mean','std'],'solutionLength':['mean']}).to_latex()
# Out:
#             compTime             solutionLength
#                 mean         std           mean
# optLevel
# 0         317.506607  871.971887       8.607143
# 1           6.053214    3.516071       8.607143
# 2           7.158607    4.091510       8.607143
# 3         158.128179  461.414629       8.607143

# %%
dataClean.sort_values('solutionLength').loc[:,['optLevel','solutionLength','compTime']]
# Out:
#      optLevel  solutionLength  compTime
# 89          1               1     2.465
# 38          2               1     2.386
# 39          3               1     2.755
# 88          0               1     2.854
# 37          1               1     2.169
# 90          2               1     2.908
# 91          3               1     2.686
# 36          0               1     2.616
# 53          1               2     2.563
# 52          0               2     2.868
# 54          2               2     3.024
# 55          3               2     3.336
# 105         1               3     3.705
# 106         2               3     4.314
# 107         3               3     4.240
# 110         2               3     3.868
# 96          0               3     3.647
# 99          3               3     4.694
# 97          1               3     3.721
# 43          3               3     3.406
# 42          2               3     3.574
# 41          1               3     3.326
# 40          0               3     3.613
# 108         0               3     4.959
# 109         1               3     3.735
# 104         0               3     3.998
# 98          2               3     4.823
# 111         3               3     4.030
# 69          1               4     4.011
# 95          3               4     4.538
# ..        ...             ...       ...
# 17          1              14     7.093
# 16          0              14    34.923
# 4           0              15   234.150
# 6           2              15    11.543
# 7           3              15    11.180
# 8           0              15    64.481
# 9           1              15     6.859
# 10          2              15     9.382
# 5           1              15     7.801
# 11          3              15    10.641
# 32          0              16   525.086
# 35          3              16   247.115
# 34          2              16    11.818
# 33          1              16    10.034
# 24          0              16   396.840
# 27          3              16   186.902
# 103         3              16  2110.943
# 102         2              16    14.885
# 25          1              16     8.423
# 101         1              16    13.696
# 100         0              16  3607.617
# 26          2              16    11.320
# 85          1              17    17.503
# 86          2              17    19.202
# 84          0              17  2990.551
# 87          3              17  1308.048
# 14          2              17    13.563
# 13          1              17    11.486
# 12          0              17   948.484
# 15          3              17   429.395
#
# [112 rows x 3 columns]

# %%
stdData = data.loc[data.loc[:,'file'].str.contains(r'Bomb')]
stdDataClean = stdData.dropna()

ownData = data.drop(stdData.index,axis=0)
ownDataClean = ownData.dropna()

# %%
lowDataClean = dataClean.where(dataClean.loc[:,'solutionLength'] < 14)
highDataClean = dataClean.where(dataClean.loc[:,'solutionLength'] >= 14)
lowStdDataClean = stdDataClean.where(stdDataClean.loc[:,'solutionLength'] < 14)
highStdDataClean = stdDataClean.where(stdDataClean.loc[:,'solutionLength'] >= 14)
lowOwnDataClean = ownDataClean.where(ownDataClean.loc[:,'solutionLength'] < 14)
highOwnDataClean = ownDataClean.where(ownDataClean.loc[:,'solutionLength'] >= 14)

# %%
data.sort_values(['file','optLevel']).groupby('optlevel')
# Out:
#                                        file  optLevel  foundSolution  \
# 36                     ./Bombastic1_1.param         0           True
# 37                     ./Bombastic1_1.param         1           True
# 38                     ./Bombastic1_1.param         2           True
# 39                     ./Bombastic1_1.param         3           True
# 52                     ./Bombastic2_2.param         0          False
# 53                     ./Bombastic2_2.param         1          False
# 54                     ./Bombastic2_2.param         2          False
# 55                     ./Bombastic2_2.param         3          False
# 40                     ./Bombastic2_3.param         0           True
# 41                     ./Bombastic2_3.param         1           True
# 42                     ./Bombastic2_3.param         2           True
# 43                     ./Bombastic2_3.param         3           True
# 20                     ./Bombastic3_5.param         0          False
# 21                     ./Bombastic3_5.param         1          False
# 22                     ./Bombastic3_5.param         2          False
# 23                     ./Bombastic3_5.param         3          False
# 28                     ./Bombastic3_6.param         0           True
# 29                     ./Bombastic3_6.param         1           True
# 30                     ./Bombastic3_6.param         2           True
# 31                     ./Bombastic3_6.param         3           True
# 60                     ./Bombastic4_7.param         0          False
# 61                     ./Bombastic4_7.param         1          False
# 62                     ./Bombastic4_7.param         2          False
# 63                     ./Bombastic4_7.param         3          False
# 48                     ./Bombastic4_8.param         0           True
# 49                     ./Bombastic4_8.param         1           True
# 50                     ./Bombastic4_8.param         2           True
# 51                     ./Bombastic4_8.param         3           True
# 0                     ./Bombastic5_10.param         0           True
# 1                     ./Bombastic5_10.param         1           True
# ..                                      ...       ...            ...
# 86   ./ownDesigns/BigComplex_possible.param         2           True
# 87   ./ownDesigns/BigComplex_possible.param         3           True
# 108         ./ownDesigns/L_impossible.param         0          False
# 109         ./ownDesigns/L_impossible.param         1          False
# 110         ./ownDesigns/L_impossible.param         2          False
# 111         ./ownDesigns/L_impossible.param         3          False
# 104           ./ownDesigns/L_possible.param         0           True
# 105           ./ownDesigns/L_possible.param         1           True
# 106           ./ownDesigns/L_possible.param         2           True
# 107           ./ownDesigns/L_possible.param         3           True
# 68            ./ownDesigns/T_possilbe.param         0           True
# 69            ./ownDesigns/T_possilbe.param         1           True
# 70            ./ownDesigns/T_possilbe.param         2           True
# 71            ./ownDesigns/T_possilbe.param         3           True
# 80   ./ownDesigns/WideOpen_impossible.param         0           True
# 81   ./ownDesigns/WideOpen_impossible.param         1           True
# 82   ./ownDesigns/WideOpen_impossible.param         2           True
# 83   ./ownDesigns/WideOpen_impossible.param         3           True
# 76     ./ownDesigns/WideOpen_possible.param         0           True
# 77     ./ownDesigns/WideOpen_possible.param         1           True
# 78     ./ownDesigns/WideOpen_possible.param         2           True
# 79     ./ownDesigns/WideOpen_possible.param         3           True
# 72       ./ownDesigns/iceT_impossible.param         0          False
# 73       ./ownDesigns/iceT_impossible.param         1          False
# 74       ./ownDesigns/iceT_impossible.param         2          False
# 75       ./ownDesigns/iceT_impossible.param         3          False
# 92         ./ownDesigns/iceT_possible.param         0          False
# 93         ./ownDesigns/iceT_possible.param         1          False
# 94         ./ownDesigns/iceT_possible.param         2          False
# 95         ./ownDesigns/iceT_possible.param         3          False
#
#      solutionLength  compTime
# 36                1     2.616
# 37                1     2.169
# 38                1     2.386
# 39                1     2.755
# 52                2     2.868
# 53                2     2.563
# 54                2     3.024
# 55                2     3.336
# 40                3     3.613
# 41                3     3.326
# 42                3     3.574
# 43                3     3.406
# 20                5     3.680
# 21                5     3.848
# 22                5     4.373
# 23                5     4.725
# 28                6     4.026
# 29                6     4.412
# 30                6     5.206
# 31                6     5.486
# 60                7     4.634
# 61                7     5.240
# 62                7     5.592
# 63                7     6.888
# 48                8     4.606
# 49                8     5.010
# 50                8     5.823
# 51                8     7.403
# 0                10     5.639
# 1                10     6.123
# ..              ...       ...
# 86               17    19.202
# 87               17  1308.048
# 108               3     4.959
# 109               3     3.735
# 110               3     3.868
# 111               3     4.030
# 104               3     3.998
# 105               3     3.705
# 106               3     4.314
# 107               3     4.240
# 68                4     4.079
# 69                4     4.011
# 70                4     4.583
# 71                4     4.871
# 80                9     4.707
# 81                9     5.322
# 82                9     5.927
# 83                9     7.569
# 76               10     5.220
# 77               10     5.230
# 78               10     6.498
# 79               10     7.774
# 72                4     4.007
# 73                4     3.816
# 74                4     3.830
# 75                4     4.007
# 92                4     3.539
# 93                4     3.904
# 94                4     4.104
# 95                4     4.538
#
# [112 rows x 5 columns]

# %%
#Taken from https://stackoverflow.com/questions/15465645/plotting-results-of-pandas-groupby#15466103
for key, grp in stdDataClean.sort_values('solutionLength').groupby(['optLevel']):
    label = "O" + str(int(key))
    plt.plot(grp['solutionLength'],grp['compTime'], label = label)
    plt.xlabel('SolutionLength')
    plt.ylabel('CPU sec(s)')
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
#Taken from https://stackoverflow.com/questions/15465645/plotting-results-of-pandas-groupby#15466103
for key, grp in lowStdDataClean.sort_values('solutionLength').groupby(['optLevel']):
    label = "O" + str(int(key))
    plt.plot(grp['solutionLength'],grp['compTime'], label=label)
    plt.xlabel('SolutionLength')
    plt.ylabel('CPU sec(s)')
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
#Taken from https://stackoverflow.com/questions/15465645/plotting-results-of-pandas-groupby#15466103
for key, grp in highStdDataClean.sort_values('solutionLength').groupby(['optLevel']):
    label = "O" + str(int(key))
    plt.plot(grp['solutionLength'],grp['compTime'], label=label)
    plt.xlabel('SolutionLength')
    plt.ylabel('CPU sec(s)')
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
#Taken from https://stackoverflow.com/questions/15465645/plotting-results-of-pandas-groupby#15466103
fig = plt.figure()
for key, grp in lowOwnDataClean.sort_values('file').groupby(['optLevel']):
    label = "O" + str(key)
    plt.plot(grp['file'],grp['compTime'], label=label)
    plt.xlabel('File')
    plt.ylabel('CPU sec(s)')
plt.legend(loc='best')

for tick in fig.get_xticklabels():
    tick.set_rotation(45)
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-86b4bbeb99a6> in <module>()
#       8 plt.legend(loc='best')
#       9
# ---> 10 for tick in fig.get_xticklabels():
#      11     tick.set_rotation(45)
#      12 plt.grid()
#
# AttributeError: 'Figure' object has no attribute 'get_xticklabels'

# %%
#Taken from https://stackoverflow.com/questions/15465645/plotting-results-of-pandas-groupby#15466103
for key, grp in highOwnDataClean.sort_values('solutionLength').groupby(['optLevel']):
    plt.bar(grp['solutionLength'],grp['compTime'], label=key)
    plt.xlabel('SolutionLength')
    plt.ylabel('CPU sec(s)')
plt.legend(loc='best')
plt.grid()
plt.show()
